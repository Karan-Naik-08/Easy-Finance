# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('MagicBricks.csv')

# %%
df.head(20)
# Out:
#          Area  BHK  Bathroom      Furnishing Locality  Parking     Price  \
# 0    800.0000    3       2.0  Semi-Furnished   Rohini      1.0   6500000
# 1    750.0000    2       2.0  Semi-Furnished   Rohini      1.0   5000000
# 2    950.0000    2       2.0       Furnished   Rohini      1.0  15500000
# 3    600.0000    2       2.0  Semi-Furnished   Rohini      1.0   4200000
# 4    650.0000    2       2.0  Semi-Furnished   Rohini      1.0   6200000
# 5   1300.0000    4       3.0  Semi-Furnished   Rohini      1.0  15500000
# 6   1350.0000    4       3.0  Semi-Furnished   Rohini      1.0  10000000
# 7    650.0000    2       2.0  Semi-Furnished   Rohini      1.0   4000000
# 8    985.0000    3       3.0     Unfurnished   Rohini      1.0   6800000
# 9   1300.0000    4       4.0  Semi-Furnished   Rohini      1.0  15000000
# 10  1100.0000    3       2.0  Semi-Furnished   Rohini      1.0   6200000
# 11   870.0000    3       2.0  Semi-Furnished   Rohini      1.0   7700000
# 12   630.0000    2       2.0  Semi-Furnished   Rohini      1.0   5500000
# 13   660.0000    2       2.0  Semi-Furnished   Rohini      1.0   5000000
# 14   344.4448    2       2.0  Semi-Furnished   Rohini      1.0   3310000
# 15   660.0000    2       2.0  Semi-Furnished   Rohini      1.0   4700000
# 16   550.0000    2       2.0  Semi-Furnished   Rohini      1.0   4500000
# 17  1100.0000    4       3.0  Semi-Furnished   Rohini      1.0  17000000
# 18  1150.0000    3       3.0  Semi-Furnished   Rohini      1.0  25000000
# 19   650.0000    2       2.0  Semi-Furnished   Rohini      1.0   6000000
#
#            Status   Transaction           Type  Per_Sqft
# 0   Ready_to_move  New_Property  Builder_Floor       NaN
# 1   Ready_to_move  New_Property      Apartment    6667.0
# 2   Ready_to_move        Resale      Apartment    6667.0
# 3   Ready_to_move        Resale  Builder_Floor    6667.0
# 4   Ready_to_move  New_Property  Builder_Floor    6667.0
# 5   Ready_to_move  New_Property  Builder_Floor    6667.0
# 6   Ready_to_move        Resale  Builder_Floor    6667.0
# 7   Ready_to_move  New_Property      Apartment    6154.0
# 8    Almost_ready  New_Property  Builder_Floor    6154.0
# 9   Ready_to_move  New_Property  Builder_Floor    6154.0
# 10  Ready_to_move  New_Property  Builder_Floor    6154.0
# 11  Ready_to_move  New_Property  Builder_Floor    6154.0
# 12  Ready_to_move  New_Property  Builder_Floor    6154.0
# 13  Ready_to_move        Resale  Builder_Floor    6154.0
# 14  Ready_to_move        Resale  Builder_Floor    6154.0
# 15  Ready_to_move  New_Property  Builder_Floor    6154.0
# 16  Ready_to_move  New_Property  Builder_Floor    6154.0
# 17  Ready_to_move  New_Property  Builder_Floor    6154.0
# 18  Ready_to_move        Resale      Apartment    6154.0
# 19  Ready_to_move        Resale  Builder_Floor    6154.0

# %%
df.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1259.000000  1259.000000  1257.000000  1226.000000  1.259000e+03
# mean    1466.452724     2.796664     2.556086     1.935563  2.130670e+07
# std     1568.055040     0.954425     1.042220     6.279212  2.560115e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.700000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.550000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1018.000000
# mean    15690.136542
# std     21134.738568
# min      1259.000000
# 25%      6364.000000
# 50%     11291.500000
# 75%     18000.000000
# max    183333.000000

# %%
df.nunique()
# Out:
# Area           315
# BHK              8
# Bathroom         7
# Furnishing       3
# Locality        34
# Parking          9
# Price          284
# Status           2
# Transaction      2
# Type             2
# Per_Sqft       251
# dtype: int64

# %%
df.shape
# Out:
# (1259, 11)

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
df['Bathroom']=df['Bathroom'].fillna(2)
df['Parking']=df['Parking'].fillna(2)

# %%
df['Furnishing'].unique()
# Out:
# array(['Semi-Furnished', 'Furnished', 'Unfurnished', nan], dtype=object)

# %%
sns.countplot(x=df['Furnishing'])
# Out:
# <AxesSubplot:xlabel='Furnishing', ylabel='count'>

# %%
df['Furnishing']=df['Furnishing'].fillna('Semi-Furnished')

# %%
df['Type'].unique()
# Out:
# array(['Builder_Floor', 'Apartment', nan], dtype=object)

# %%
sns.countplot(x=df['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
df['Type']=df['Type'].fillna('Apartment')

# %%
sq_mean= df['Per_Sqft'].mean()

# %%
df['Per_Sqft']=df['Per_Sqft'].fillna(sq_mean)

# %%
df.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Area', 'BHK', 'Bathroom', 'Furnishing', 'Locality', 'Parking', 'Price',
#        'Status', 'Transaction', 'Type', 'Per_Sqft'],
#       dtype='object')

# %%
colnm=['BHK', 'Bathroom', 'Furnishing', 'Locality', 'Parking', 'Price',
       'Status', 'Transaction', 'Type', 'Per_Sqft']

# %%
for i in colnm:
  sns.countplot(x=df[i])
  plt.show()

# %%
sns.pairplot(df,hue='Price')

# %%
sns.scatterplot(x=df['Area'],y=df['Price'],hue=df['Price'])
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Price'>

# %%
for i in colnm:
   sns.scatterplot(x=df[i],y=df['Price'],hue=df['Price'])
   plt.show()

# %%
df=df[
      (df.BHK <= 6)
     & (df.Bathroom<=6)
     & (df.Area<=11000)
    
]

# %%
sns.scatterplot(x=df['Area'],y=df['Price'],hue=df['Price'])
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Price'>

# %%
df['Locality'].unique()
# Out:
# array(['Rohini', 'Lajpat Nagar', 'Dwarka', 'Budh Vihar', 'Rohini ',
#        'New Friends Colony', 'Greater Kailash', 'Shahdara', 'Laxmi Nagar',
#        'Uttam Nagar', 'Patel Nagar West', 'Vasant Kunj', 'Geeta Colony',
#        'Saket', 'Safdarjung Enclave', 'Paschim Vihar', 'Alaknanda',
#        'Mathura Road', 'Sultanpur', 'Chhattarpur', 'Mehrauli',
#        'Mahavir Enclave', 'Narela', 'Malviya Nagar', 'Dilshad Garden',
#        'Vasundhara Enclave', 'Okhla', 'Karol Bagh', 'Kirti Nagar',
#        'Sheikh Sarai', 'Punjabi Bagh', 'Kalkaji', 'Hauz Khas',
#        'Chittaranjan Park'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df['Furnishing']=le.fit_transform(df['Furnishing'])
df['Type']=le.fit_transform(df['Type'])
df['Transaction']=le.fit_transform(df['Transaction'])
df['Status']=le.fit_transform(df['Status'])
df['Locality']=le.fit_transform(df['Locality'])



print(df['Furnishing'].unique())
print (df['Type'].unique())
print( df['Transaction'].unique())
print( df['Status'].unique())
print( df['Locality'].unique())
# Out:
# [1 0 2]
# [1 0]
# [0 1]
# [1 0]
# [24 12  5  1 25 19  7 28 13 31 22 32  6 27 26 21  0 16 30  2 17 14 18 15
#   4 33 20 10 11 29 23  9  8  3]

# %%
df['Locality']
# Out:
# 0       24
# 1       24
# 2       24
# 3       24
# 4       24
#         ..
# 1254     3
# 1255     3
# 1256     3
# 1257     3
# 1258     3
# Name: Locality, Length: 1259, dtype: int32

# %%
df['Bathroom']= df['Bathroom'].astype(int)
df['Parking']= df['Parking'].astype(int)
df['Area']= df['Area'].astype(int)

# %%
df['Area']
# Out:
# 0        800
# 1        750
# 2        950
# 3        600
# 4        650
#         ...
# 1253    1200
# 1254    4118
# 1255    1050
# 1256     875
# 1257     990
# Name: Area, Length: 1248, dtype: int32

# %%
x=df.drop(['Price','Per_Sqft' ],axis=1)
y=df['Price']

# %%
print(x)
print(y)
# Out:
#       Area  BHK  Bathroom  Furnishing  Locality  Parking  Status  Transaction  \
# 0      800    3         2           1        24        1       1            0
# 1      750    2         2           1        24        1       1            0
# 2      950    2         2           0        24        1       1            1
# 3      600    2         2           1        24        1       1            1
# 4      650    2         2           1        24        1       1            0
# ...    ...  ...       ...         ...       ...      ...     ...          ...
# 1253  1200    3         3           1         3        1       1            1
# 1254  4118    4         5           2         3        3       1            0
# 1255  1050    3         2           1         3        3       1            1
# 1256   875    3         3           1         3        3       1            0
# 1257   990    2         2           2         3        1       1            1
#
#       Type
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
# ...    ...
# 1253     1
# 1254     1
# 1255     1
# 1256     1
# 1257     1
#
# [1248 rows x 9 columns]
# 0        6500000
# 1        5000000
# 2       15500000
# 3        4200000
# 4        6200000
#           ...
# 1253    16500000
# 1254    55000000
# 1255    12500000
# 1256    17500000
# 1257    11500000
# Name: Price, Length: 1248, dtype: int64

# %%
x.columns
# Out:
# Index(['Area', 'BHK', 'Bathroom', 'Furnishing', 'Locality', 'Parking',
#        'Status', 'Transaction', 'Type'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

LR=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=LR.predict(x_test)
error=r2_score(y_test,pred)
error
# Out:
# 0.7306758682468694

# %%
inpt=np.array([['800','3','2','1','24','2','1','0','1']])

# %%
from num2words import num2words

# %%
def give_pred(inpt):
    inpt=inpt.astype(int)
    predictin=LR.predict(inpt)
    in_words=num2words(predictin,lang='en_IN')
    return in_words

# %%
give_pred(inpt)
# Out:
# c:\Users\manas\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 'eighty-eight lakh, thirteen thousand, eight hundred and thirty-four point one four nine nine seven six six eight three'
